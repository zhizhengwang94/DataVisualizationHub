# %%
import numpy as np
import pandas as pd

# %%
crimes = pd.read_csv('data/Crimes_With_Dates_Cleaned.csv')
# Out:
# C:\Users\zhizh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (2,4,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
crimes.head()
# Out:
#    Unnamed: 0  Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0           0    201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1           1    201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2           2    201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3           3    201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4           4    201204355         2204  180043926  09/03/2018 12:06:54 PM
#
#   NIBRS Code  Victims             Crime Name1                     Crime Name2  \
# 0        35B        1   Crime Against Society       Drug Equipment Violations
# 1        35A        1   Crime Against Society        Drug/Narcotic Violations
# 2        35A        1   Crime Against Society        Drug/Narcotic Violations
# 3        35A        1   Crime Against Society        Drug/Narcotic Violations
# 4        220        1  Crime Against Property  Burglary/Breaking and Entering
#
# ...

# %%
crimes_by_year = crimes['Year'].value_counts().sort_index(ascending=True)
crimes_by_month_2020 = crimes[crimes['Year'] == 2020]['Month'].value_counts().sort_index(ascending=True)
crimes_by_month_2021 = crimes[crimes['Year'] == 2021]['Month'].value_counts().sort_index(ascending=True)
crimes_by_month_2022 = crimes[crimes['Year'] == 2022]['Month'].value_counts().sort_index(ascending=True)
crimes_in_January_2021_by_day = crimes[crimes['Year-Month'] == '2021-01']['Day'].value_counts().sort_index(ascending=True)

crimes_by_month_2020
# Out:
# 1     4204
# 2     4158
# 3     3963
# 4     2906
# 5     3613
# 6     3462
# 7     3840
# 8     3771
# 9     3832
# 10    3775
# 11    3618
# 12    3770
# Name: Month, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.plot(crimes_by_year.index, crimes_by_year.values)
plt.title('Crimes committed in the US')
plt.ylabel('Crime count')
plt.xlabel('Time (years)')
plt.show()
plt.clf()

plt.plot(crimes_by_month_2020.index, crimes_by_month_2020.values)
plt.xlabel('Time (months in 2020)')
plt.ylabel('Crime count')
plt.show()
plt.clf()

plt.plot(crimes_by_month_2021.index, crimes_by_month_2021.values)
plt.xlabel('Time (months in 2021)')
plt.ylabel('Crime count')
plt.show()
plt.clf()

plt.plot(crimes_in_January_2021_by_day.index, crimes_in_January_2021_by_day.values)
plt.xlabel('Time (days in January 2021)')
plt.ylabel('Crime count')
plt.show()
plt.clf()

plt.plot(crimes_by_month_2022.index, crimes_by_month_2022.values)
plt.xlabel('Time (months in 2022)')
plt.ylabel('Crime count')
plt.show()
plt.clf()
